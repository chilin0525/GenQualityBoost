# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import shutil
import tempfile

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from monai import transforms
from monai.apps import MedNISTDataset
from monai.config import print_config
from monai.data import DataLoader, Dataset
from monai.utils import first, set_determinism
from torch.cuda.amp import GradScaler, autocast
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from PIL import Image

from generative.inferers import LatentDiffusionInferer
from generative.losses.adversarial_loss import PatchAdversarialLoss
from generative.losses.perceptual import PerceptualLoss
from generative.networks.nets import AutoencoderKL, DiffusionModelUNet, PatchDiscriminator
from generative.networks.schedulers import DDPMScheduler

print_config()
# Out:
# MONAI version: 1.3.1
# Numpy version: 1.26.4
# Pytorch version: 2.3.0+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 96bfda00c6bd290297f5e3514ea227c6be4d08b4
# MONAI __file__: /home/<username>/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: NOT INSTALLED or UNKNOWN VERSION.
# scikit-image version: NOT INSTALLED or UNKNOWN VERSION.
# scipy version: 1.13.0
# Pillow version: 10.3.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.18.0+cu121
# tqdm version: 4.66.4
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.8
# pandas version: NOT INSTALLED or UNKNOWN VERSION.
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## config

# %%
random_seed = 26
image_size = 128

# affect select which type data
# and path of generated result to save
# and path of trained model name
gen_type = "pneumonia_bac"
root_dir = f"./latent_diffusion"
model_path = f"./{root_dir}/model"
os.makedirs(root_dir, exist_ok=True)
os.makedirs(model_path, exist_ok=True)

AUGMENTATION_GAN_root_dir = "./AUGMENTATION_GAN"
CLASSIC_AUG_DIR = os.path.join(AUGMENTATION_GAN_root_dir, 'train_classic', '3000')

normal_src_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train', 'normal')
normal_500_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '500', 'normal')
normal_1000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '1000', 'normal')
normal_2000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '2000', 'normal')

# normal_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '3000', 'normal')
covid_src_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train', 'covid')
covid_500_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '500', 'covid')
covid_1000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '1000', 'covid')
covid_2000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '2000', 'covid')

pneumonia_bac_src_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train', 'pneumonia_bac')
pneumonia_bac_500_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '500', 'pneumonia_bac')
pneumonia_bac_1000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '1000', 'pneumonia_bac')
pneumonia_bac_2000_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '2000', 'pneumonia_bac')

pneumonia_vir_dir = os.path.join(AUGMENTATION_GAN_root_dir, 'custom_covid_dataset', 'train_classic', '3000', 'pneumonia_vir')

# %% [markdown]
# ## setup random seed

# %%
set_determinism(random_seed)

# %% [markdown]
# ## prepare train/val dataloader

# %%
gen_type
# Out:
# 'pneumonia_bac'

# %%
def get_files(path):
    return [os.path.join(path, i) for i in os.listdir(path) if i.endswith("jpeg") or i.endswith("jpg") or i.endswith("png")]
            
gen_training_img = {
    'normal': get_files(normal_src_dir) +\
            get_files(normal_500_dir) +\
            get_files(normal_1000_dir) +\
            get_files(normal_2000_dir),
    'covid': get_files(covid_src_dir) +\
            get_files(covid_500_dir) +\
            get_files(covid_1000_dir) +\
            get_files(covid_2000_dir),
    'pneumonia_bac': get_files(pneumonia_bac_src_dir) +\
            get_files(pneumonia_bac_500_dir) +\
            get_files(pneumonia_bac_1000_dir)
}

# %%
images = [{'image': i} for i in  gen_training_img[gen_type]]
train_imgs, val_imgs = train_test_split(images)

# %%
print(f"training images: {len(train_imgs)}, val images: {len(val_imgs)}")
# Out:
# training images: 802, val images: 268

# %%
image_size
# Out:
# 128

# %%
from PIL import Image

class ChestDataset(Dataset):
    def __init__(self, imgs, label, transform=None):
        self.transform = transform
        self.imgs = imgs
        self.label = label

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        image = Image.open(self.imgs[idx]).convert("RGB")
        if self.transform is not None:
            image = self.transform(image)
        return {'image': image}

train_transforms = transforms.Compose([
        transforms.LoadImaged(keys=["image"]),
        transforms.EnsureChannelFirstd(keys=["image"]),
        transforms.Resized(keys="image", spatial_size=(128, 128)),
        transforms.ScaleIntensityRanged(keys=["image"], a_min=0.0, a_max=255.0, b_min=0.0, b_max=1.0, clip=True),
        transforms.RandAffined(
            keys=["image"],
            # rotate_range=[(-np.pi / 36, np.pi / 36), (-np.pi / 36, np.pi / 36)],
            translate_range=[(-1, 1), (-1, 1)],
            scale_range=[(-0.05, 0.05), (-0.05, 0.05)],
            spatial_size=[image_size, image_size],
            padding_mode="zeros",
            prob=0.5,
        ),
    ]
)

val_transforms = transforms.Compose([
        transforms.LoadImaged(keys=["image"]),
        transforms.EnsureChannelFirstd(keys=["image"]),
        transforms.Resized(keys="image", spatial_size=(128, 128)),
        transforms.ScaleIntensityRanged(keys=["image"], a_min=0.0, a_max=255.0, b_min=0.0, b_max=1.0, clip=True),
    ]
)

device = torch.device("cuda:1")
from torch.utils.data.dataloader import default_collate

train_ds = Dataset(data = train_imgs, transform = train_transforms)
val_ds = Dataset(data = val_imgs, transform = val_transforms)
train_loader = DataLoader(
    train_ds, 
    batch_size=32, 
    shuffle=True, 
    num_workers=8,
    pin_memory=True,
)
val_loader = DataLoader(
    val_ds, 
    batch_size=32, 
    shuffle=True, 
    num_workers=8, 
    pin_memory=True,
)

# %% [markdown]
# ## display from train and val dataloader

# %%
for img in train_loader:
    print(img['image'].shape)
    break
# Out:
# torch.Size([32, 3, 128, 128])

# %%
train_demo = first(train_loader)
fig, ax = plt.subplots(nrows=1, ncols=3)
for image_n in range(3):
    ax[image_n].imshow(train_demo["image"][image_n, 0, :, :].T, cmap="gray")
    ax[image_n].axis("off")

# %%
for img in val_loader:
    print(img['image'].shape)
    break
# Out:
# torch.Size([32, 3, 128, 128])

# %%
train_demo = first(val_loader)
fig, ax = plt.subplots(nrows=1, ncols=3)
for image_n in range(3):
    ax[image_n].imshow(train_demo["image"][image_n, 0, :, :].T, cmap="gray")
    ax[image_n].axis("off")

# %% [markdown]
# ## training

# %%
import torch.nn as nn

autoencoderkl = AutoencoderKL(
    spatial_dims=2,
    in_channels=3,
    out_channels=3,
    num_channels=(128, 128, 256),
    latent_channels=3,
    num_res_blocks=2,
    attention_levels=(False, False, False),
    with_encoder_nonlocal_attn=False,
    with_decoder_nonlocal_attn=False,
)
# autoencoderkl = nn.DataParallel(autoencoderkl)
autoencoderkl = autoencoderkl.to(device)

# %%
perceptual_loss = PerceptualLoss(spatial_dims=2, network_type="alex")
perceptual_loss.to(device)
perceptual_weight = 0.001
# Out:
# /home/chilin/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/chilin/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
discriminator = PatchDiscriminator(spatial_dims=2, num_layers_d=3, num_channels=64, in_channels=3, out_channels=3)
discriminator = discriminator.to(device)

adv_loss = PatchAdversarialLoss(criterion="least_squares")
adv_weight = 0.01

# %%
optimizer_g = torch.optim.Adam(autoencoderkl.parameters(), lr=1e-4)
optimizer_d = torch.optim.Adam(discriminator.parameters(), lr=5e-4)

# For mixed precision training
scaler_g = torch.cuda.amp.GradScaler()
scaler_d = torch.cuda.amp.GradScaler()

# %%
len(train_loader)
# Out:
# 26

# %%
kl_weight = 1e-6
n_epochs = 300
val_interval = 10
autoencoder_warm_up_n_epochs = 10

epoch_recon_losses = []
epoch_gen_losses = []
epoch_disc_losses = []
val_recon_losses = []
intermediary_images = []
num_example_images = 4

best_val_loss_autoencoder = float('inf')

for epoch in range(n_epochs):
    autoencoderkl.train()
    discriminator.train()
    epoch_loss = 0
    gen_epoch_loss = 0
    disc_epoch_loss = 0
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), ncols=110)
    progress_bar.set_description(f"Epoch {epoch}")
    for step, batch in progress_bar:
        images = batch["image"].to(device)
        optimizer_g.zero_grad(set_to_none=True)

        with autocast(enabled=True):
            reconstruction, z_mu, z_sigma = autoencoderkl(images)

            recons_loss = F.l1_loss(reconstruction.float(), images.float())
            p_loss = perceptual_loss(reconstruction.float(), images.float())
            kl_loss = 0.5 * torch.sum(z_mu.pow(2) + z_sigma.pow(2) - torch.log(z_sigma.pow(2)) - 1, dim=[1, 2, 3])
            kl_loss = torch.sum(kl_loss) / kl_loss.shape[0]
            loss_g = recons_loss + (kl_weight * kl_loss) + (perceptual_weight * p_loss)

            if epoch > autoencoder_warm_up_n_epochs:
                logits_fake = discriminator(reconstruction.contiguous().float())[-1]
                generator_loss = adv_loss(logits_fake, target_is_real=True, for_discriminator=False)
                loss_g += adv_weight * generator_loss

        scaler_g.scale(loss_g).backward()
        scaler_g.step(optimizer_g)
        scaler_g.update()

        if epoch > autoencoder_warm_up_n_epochs:
            with autocast(enabled=True):
                optimizer_d.zero_grad(set_to_none=True)

                logits_fake = discriminator(reconstruction.contiguous().detach())[-1]
                loss_d_fake = adv_loss(logits_fake, target_is_real=False, for_discriminator=True)
                logits_real = discriminator(images.contiguous().detach())[-1]
                loss_d_real = adv_loss(logits_real, target_is_real=True, for_discriminator=True)
                discriminator_loss = (loss_d_fake + loss_d_real) * 0.5

                loss_d = adv_weight * discriminator_loss

            scaler_d.scale(loss_d).backward()
            scaler_d.step(optimizer_d)
            scaler_d.update()

        epoch_loss += recons_loss.item()
        if epoch > autoencoder_warm_up_n_epochs:
            gen_epoch_loss += generator_loss.item()
            disc_epoch_loss += discriminator_loss.item()

        progress_bar.set_postfix(
            {
                "recons_loss": epoch_loss / (step + 1),
                "gen_loss": gen_epoch_loss / (step + 1),
                "disc_loss": disc_epoch_loss / (step + 1),
            }
        )
    epoch_recon_losses.append(epoch_loss / (step + 1))
    epoch_gen_losses.append(gen_epoch_loss / (step + 1))
    epoch_disc_losses.append(disc_epoch_loss / (step + 1))

    if (epoch + 1) % val_interval == 0:
        autoencoderkl.eval()
        val_loss = 0
        with torch.no_grad():
            for val_step, batch in enumerate(val_loader, start=1):
                images = batch["image"].to(device)

                with autocast(enabled=True):
                    reconstruction, z_mu, z_sigma = autoencoderkl(images)
                    # Get the first reconstruction from the first validation batch for visualisation purposes
                    if val_step == 1:
                        intermediary_images.append(reconstruction[:num_example_images, 0])

                    recons_loss = F.l1_loss(images.float(), reconstruction.float())

                val_loss += recons_loss.item()

        val_loss /= val_step
        val_recon_losses.append(val_loss)

        # Save the autoencoder model if it has the best validation loss so far
        if val_loss < best_val_loss_autoencoder:
            best_val_loss_autoencoder = val_loss
            torch.save(autoencoderkl.state_dict(), os.path.join(model_path, f"{gen_type}_best_autoencoderkl.pth"))
            print(f"Saved better autoencoder model at epoch {epoch + 1} with val loss: {val_loss:.4f}")

        
        print(f"epoch {epoch + 1} val loss: {val_loss:.4f}")
progress_bar.close()

del discriminator
del perceptual_loss
torch.cuda.empty_cache()
# Out:
# Epoch 0:  96%|███████████████████▏| 25/26 [00:12<00:00,  2.35it/s, recons_loss=0.292, gen_loss=0, disc_loss=0]/home/chilin/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 0: 100%|████████████████████| 26/26 [00:12<00:00,  2.12it/s, recons_loss=0.286, gen_loss=0, disc_loss=0]
# Epoch 1: 100%|███████████████████| 26/26 [00:14<00:00,  1.82it/s, recons_loss=0.0953, gen_loss=0, disc_loss=0]
# Epoch 2: 100%|███████████████████| 26/26 [00:15<00:00,  1.67it/s, recons_loss=0.0831, gen_loss=0, disc_loss=0]
# Epoch 3: 100%|███████████████████| 26/26 [00:16<00:00,  1.61it/s, recons_loss=0.0611, gen_loss=0, disc_loss=0]
# Epoch 4: 100%|███████████████████| 26/26 [00:16<00:00,  1.56it/s, recons_loss=0.0488, gen_loss=0, disc_loss=0]
# Epoch 5: 100%|███████████████████| 26/26 [00:16<00:00,  1.56it/s, recons_loss=0.0454, gen_loss=0, disc_loss=0]
# Epoch 6: 100%|███████████████████| 26/26 [00:17<00:00,  1.53it/s, recons_loss=0.0549, gen_loss=0, disc_loss=0]
# Epoch 7: 100%|███████████████████| 26/26 [00:16<00:00,  1.55it/s, recons_loss=0.0539, gen_loss=0, disc_loss=0]
# Epoch 8: 100%|███████████████████| 26/26 [00:16<00:00,  1.54it/s, recons_loss=0.0398, gen_loss=0, disc_loss=0]
# Epoch 9: 100%|███████████████████| 26/26 [00:16<00:00,  1.54it/s, recons_loss=0.0395, gen_loss=0, disc_loss=0]
# Saved better autoencoder model at epoch 10 with val loss: 0.0357
# epoch 10 val loss: 0.0357
# Epoch 10: 100%|██████████████████| 26/26 [00:16<00:00,  1.54it/s, recons_loss=0.0333, gen_loss=0, disc_loss=0]
# Epoch 11:  96%|███████████▌| 25/26 [00:17<00:00,  1.42it/s, recons_loss=0.043, gen_loss=1.47, disc_loss=0.937]/home/chilin/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/torch/_tensor.py:1443: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   ret = func(*args, **kwargs)
# Epoch 11: 100%|███████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0434, gen_loss=1.46, disc_loss=0.925]
# Epoch 12: 100%|██████████| 26/26 [00:17<00:00,  1.46it/s, recons_loss=0.0577, gen_loss=0.885, disc_loss=0.514]
# Epoch 13: 100%|██████████| 26/26 [00:17<00:00,  1.45it/s, recons_loss=0.0406, gen_loss=0.357, disc_loss=0.314]
# Epoch 14: 100%|███████████| 26/26 [00:17<00:00,  1.45it/s, recons_loss=0.0308, gen_loss=0.275, disc_loss=0.27]
# Epoch 15: 100%|██████████| 26/26 [00:17<00:00,  1.45it/s, recons_loss=0.0383, gen_loss=0.262, disc_loss=0.261]
# Epoch 16: 100%|███████████| 26/26 [00:17<00:00,  1.44it/s, recons_loss=0.0378, gen_loss=0.26, disc_loss=0.258]
# Epoch 17: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0346, gen_loss=0.274, disc_loss=0.271]
# Epoch 18: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0363, gen_loss=0.264, disc_loss=0.261]
# Epoch 19: 100%|██████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0303, gen_loss=0.256, disc_loss=0.256]
# Saved better autoencoder model at epoch 20 with val loss: 0.0257
# epoch 20 val loss: 0.0257
# Epoch 20: 100%|██████████| 26/26 [00:18<00:00,  1.44it/s, recons_loss=0.0252, gen_loss=0.258, disc_loss=0.255]
# Epoch 21: 100%|███████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0302, gen_loss=0.26, disc_loss=0.258]
# Epoch 22: 100%|███████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0343, gen_loss=0.26, disc_loss=0.258]
# Epoch 23: 100%|███████████| 26/26 [00:18<00:00,  1.44it/s, recons_loss=0.0267, gen_loss=0.261, disc_loss=0.26]
# Epoch 24: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0239, gen_loss=0.256, disc_loss=0.254]
# Epoch 25: 100%|██████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0287, gen_loss=0.256, disc_loss=0.252]
# Epoch 26: 100%|███████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0406, gen_loss=0.26, disc_loss=0.256]
# Epoch 27: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0272, gen_loss=0.272, disc_loss=0.264]
# Epoch 28: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0375, gen_loss=0.265, disc_loss=0.259]
# Epoch 29: 100%|███████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0293, gen_loss=0.27, disc_loss=0.256]
# Saved better autoencoder model at epoch 30 with val loss: 0.0215
# epoch 30 val loss: 0.0215
# Epoch 30: 100%|██████████| 26/26 [00:18<00:00,  1.44it/s, recons_loss=0.0216, gen_loss=0.261, disc_loss=0.251]
# Epoch 31: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0223, gen_loss=0.271, disc_loss=0.256]
# Epoch 32: 100%|██████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0256, gen_loss=0.273, disc_loss=0.255]
# Epoch 33: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0285, gen_loss=0.287, disc_loss=0.254]
# Epoch 34: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0222, gen_loss=0.291, disc_loss=0.262]
# Epoch 35: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0258, gen_loss=0.295, disc_loss=0.253]
# Epoch 36: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0227, gen_loss=0.296, disc_loss=0.263]
# Epoch 37: 100%|███████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0225, gen_loss=0.309, disc_loss=0.26]
# Epoch 38: 100%|███████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0246, gen_loss=0.318, disc_loss=0.27]
# Epoch 39: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0286, gen_loss=0.383, disc_loss=0.241]
# epoch 40 val loss: 0.0276
# Epoch 40: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0241, gen_loss=0.384, disc_loss=0.285]
# Epoch 41: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0236, gen_loss=0.407, disc_loss=0.267]
# Epoch 42: 100%|██████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0245, gen_loss=0.456, disc_loss=0.272]
# Epoch 43: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0305, gen_loss=0.462, disc_loss=0.235]
# Epoch 44: 100%|███████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0255, gen_loss=0.45, disc_loss=0.272]
# Epoch 45: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0236, gen_loss=0.546, disc_loss=0.343]
# Epoch 46: 100%|███████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.022, gen_loss=0.333, disc_loss=0.294]
# Epoch 47: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0276, gen_loss=0.344, disc_loss=0.292]
# Epoch 48: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0304, gen_loss=0.348, disc_loss=0.246]
# Epoch 49: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0233, gen_loss=0.366, disc_loss=0.249]
# Saved better autoencoder model at epoch 50 with val loss: 0.0189
# epoch 50 val loss: 0.0189
# Epoch 50: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0189, gen_loss=0.349, disc_loss=0.275]
# Epoch 51: 100%|███████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0231, gen_loss=0.437, disc_loss=0.26]
# Epoch 52: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0271, gen_loss=0.509, disc_loss=0.208]
# Epoch 53: 100%|███████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0232, gen_loss=0.464, disc_loss=0.25]
# Epoch 54: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0255, gen_loss=0.622, disc_loss=0.261]
# Epoch 55: 100%|███████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.024, gen_loss=0.514, disc_loss=0.273]
# Epoch 56: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0249, gen_loss=0.419, disc_loss=0.229]
# Epoch 57: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0289, gen_loss=0.459, disc_loss=0.243]
# Epoch 58: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0297, gen_loss=0.546, disc_loss=0.217]
# Epoch 59: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0323, gen_loss=0.762, disc_loss=0.128]
# epoch 60 val loss: 0.0263
# Epoch 60: 100%|███████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0214, gen_loss=0.54, disc_loss=0.271]
# Epoch 61: 100%|████████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.024, gen_loss=0.647, disc_loss=0.22]
# Epoch 62: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0213, gen_loss=0.593, disc_loss=0.314]
# Epoch 63: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0226, gen_loss=0.495, disc_loss=0.208]
# Epoch 64: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0284, gen_loss=0.589, disc_loss=0.203]
# Epoch 65: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0231, gen_loss=0.549, disc_loss=0.255]
# Epoch 66: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0217, gen_loss=0.647, disc_loss=0.193]
# Epoch 67: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0233, gen_loss=0.594, disc_loss=0.258]
# Epoch 68: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0281, gen_loss=0.528, disc_loss=0.225]
# Epoch 69: 100%|███████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0189, gen_loss=0.445, disc_loss=0.28]
# Saved better autoencoder model at epoch 70 with val loss: 0.0153
# epoch 70 val loss: 0.0153
# Epoch 70: 100%|████████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.017, gen_loss=0.435, disc_loss=0.27]
# Epoch 71: 100%|███████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0217, gen_loss=0.525, disc_loss=0.23]
# Epoch 72: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0227, gen_loss=0.553, disc_loss=0.231]
# Epoch 73: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0196, gen_loss=0.568, disc_loss=0.241]
# Epoch 74: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0195, gen_loss=0.429, disc_loss=0.232]
# Epoch 75: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0202, gen_loss=0.494, disc_loss=0.223]
# Epoch 76: 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0218, gen_loss=0.538, disc_loss=0.205]
# Epoch 77: 100%|███████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0235, gen_loss=0.65, disc_loss=0.222]
# Epoch 78: 100%|███████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0202, gen_loss=0.621, disc_loss=0.25]
# Epoch 79: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0181, gen_loss=0.575, disc_loss=0.212]
# epoch 80 val loss: 0.0200
# Epoch 80: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0181, gen_loss=0.547, disc_loss=0.241]
# Epoch 81: 100%|████████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.02, gen_loss=0.774, disc_loss=0.188]
# Epoch 82: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0211, gen_loss=0.876, disc_loss=0.0615]
# Epoch 83: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0168, gen_loss=0.564, disc_loss=0.289]
# Epoch 84: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0222, gen_loss=0.498, disc_loss=0.196]
# Epoch 85: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0211, gen_loss=0.645, disc_loss=0.163]
# Epoch 86: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0247, gen_loss=0.833, disc_loss=0.234]
# Epoch 87: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0225, gen_loss=0.759, disc_loss=0.139]
# Epoch 88: 100%|███████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.019, gen_loss=0.784, disc_loss=0.137]
# Epoch 89: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0242, gen_loss=0.729, disc_loss=0.144]
# epoch 90 val loss: 0.0231
# Epoch 90: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0207, gen_loss=0.789, disc_loss=0.146]
# Epoch 91: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0187, gen_loss=0.782, disc_loss=0.124]
# Epoch 92: 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0227, gen_loss=0.912, disc_loss=0.101]
# Epoch 93: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0201, gen_loss=0.921, disc_loss=0.0485]
# Epoch 94: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0226, gen_loss=0.878, disc_loss=0.0505]
# Epoch 95: 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.021, gen_loss=0.921, disc_loss=0.0471]
# Epoch 96: 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.025, gen_loss=0.975, disc_loss=0.0279]
# Epoch 97: 100%|██████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0211, gen_loss=1.02, disc_loss=0.0262]
# Epoch 98: 100%|███████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0202, gen_loss=1.05, disc_loss=0.013]
# Epoch 99: 100%|███████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.018, gen_loss=1.01, disc_loss=0.0133]
# epoch 100 val loss: 0.0249
# Epoch 100: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0215, gen_loss=1.01, disc_loss=0.0195]
# Epoch 101: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0209, gen_loss=0.998, disc_loss=0.0241]
# Epoch 102: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0197, gen_loss=0.894, disc_loss=0.0387]
# Epoch 103: 100%|███████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.02, gen_loss=0.981, disc_loss=0.029]
# Epoch 104: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0303, gen_loss=1.05, disc_loss=0.018]
# Epoch 105: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.025, gen_loss=1.03, disc_loss=0.0129]
# Epoch 106: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0202, gen_loss=1.05, disc_loss=0.00484]
# Epoch 107: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0192, gen_loss=1.04, disc_loss=0.00463]
# Epoch 108: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0192, gen_loss=1.02, disc_loss=0.0111]
# Epoch 109: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0181, gen_loss=1.04, disc_loss=0.00731]
# epoch 110 val loss: 0.0154
# Epoch 110: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0254, gen_loss=1.04, disc_loss=0.00483]
# Epoch 111: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.029, gen_loss=1.04, disc_loss=0.00782]
# Epoch 112: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0218, gen_loss=1.06, disc_loss=0.00404]
# Epoch 113: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0201, gen_loss=1.04, disc_loss=0.00322]
# Epoch 114: 100%|███████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0229, gen_loss=1, disc_loss=0.00708]
# Epoch 115: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0245, gen_loss=0.584, disc_loss=0.305]
# Epoch 116: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0206, gen_loss=0.388, disc_loss=0.265]
# Epoch 117: 100%|█████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.0204, gen_loss=0.313, disc_loss=0.278]
# Epoch 118: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0176, gen_loss=0.289, disc_loss=0.269]
# Epoch 119: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0202, gen_loss=0.263, disc_loss=0.261]
# epoch 120 val loss: 0.0248
# Epoch 120: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0165, gen_loss=0.282, disc_loss=0.278]
# Epoch 121: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0144, gen_loss=0.293, disc_loss=0.269]
# Epoch 122: 100%|█████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.0156, gen_loss=0.263, disc_loss=0.261]
# Epoch 123: 100%|█████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.0141, gen_loss=0.255, disc_loss=0.253]
# Epoch 124: 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0143, gen_loss=0.27, disc_loss=0.261]
# Epoch 125: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0152, gen_loss=0.336, disc_loss=0.296]
# Epoch 126: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0203, gen_loss=0.267, disc_loss=0.254]
# Epoch 127: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0161, gen_loss=0.265, disc_loss=0.254]
# Epoch 128: 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.015, gen_loss=0.272, disc_loss=0.256]
# Epoch 129: 100%|█████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.0219, gen_loss=0.263, disc_loss=0.249]
# epoch 130 val loss: 0.0231
# Epoch 130: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0184, gen_loss=0.278, disc_loss=0.255]
# Epoch 131: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0157, gen_loss=0.271, disc_loss=0.263]
# Epoch 132: 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0154, gen_loss=0.27, disc_loss=0.261]
# Epoch 133: 100%|██████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.015, gen_loss=0.262, disc_loss=0.256]
# Epoch 134: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0144, gen_loss=0.258, disc_loss=0.252]
# Epoch 135: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0156, gen_loss=0.266, disc_loss=0.255]
# Epoch 136: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0184, gen_loss=0.266, disc_loss=0.257]
# Epoch 137: 100%|███████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0173, gen_loss=0.27, disc_loss=0.25]
# Epoch 138: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0185, gen_loss=0.273, disc_loss=0.243]
# Epoch 139: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0149, gen_loss=0.279, disc_loss=0.249]
# epoch 140 val loss: 0.0170
# Epoch 140: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0153, gen_loss=0.356, disc_loss=0.238]
# Epoch 141: 100%|█████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0159, gen_loss=0.424, disc_loss=0.191]
# Epoch 142: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0164, gen_loss=0.643, disc_loss=0.353]
# Epoch 143: 100%|██████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0177, gen_loss=0.619, disc_loss=0.14]
# Epoch 144: 100%|████████| 26/26 [00:19<00:00,  1.35it/s, recons_loss=0.0242, gen_loss=0.719, disc_loss=0.0874]
# Epoch 145: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0237, gen_loss=0.787, disc_loss=0.069]
# Epoch 146: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0191, gen_loss=0.737, disc_loss=0.103]
# Epoch 147: 100%|██████████| 26/26 [00:19<00:00,  1.34it/s, recons_loss=0.0191, gen_loss=0.9, disc_loss=0.0435]
# Epoch 148: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0197, gen_loss=0.924, disc_loss=0.029]
# Epoch 149: 100%|████████| 26/26 [00:19<00:00,  1.37it/s, recons_loss=0.0189, gen_loss=0.939, disc_loss=0.0299]
# epoch 150 val loss: 0.0204
# Epoch 150: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0195, gen_loss=0.901, disc_loss=0.0549]
# Epoch 151: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0188, gen_loss=0.962, disc_loss=0.0227]
# Epoch 152: 100%|████████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0279, gen_loss=1, disc_loss=0.0241]
# Epoch 153: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.021, gen_loss=0.988, disc_loss=0.0172]
# Epoch 154: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0198, gen_loss=0.925, disc_loss=0.0342]
# Epoch 155: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0246, gen_loss=0.958, disc_loss=0.0301]
# Epoch 156: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0186, gen_loss=0.98, disc_loss=0.0353]
# Epoch 157: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0248, gen_loss=0.999, disc_loss=0.0362]
# Epoch 158: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0195, gen_loss=0.974, disc_loss=0.0236]
# Epoch 159: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0205, gen_loss=0.904, disc_loss=0.0637]
# epoch 160 val loss: 0.0174
# Epoch 160: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0204, gen_loss=0.964, disc_loss=0.0864]
# Epoch 161: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0195, gen_loss=0.914, disc_loss=0.03]
# Epoch 162: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0172, gen_loss=1.02, disc_loss=0.0117]
# Epoch 163: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0206, gen_loss=1.04, disc_loss=0.0162]
# Epoch 164: 100%|████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0182, gen_loss=0.987, disc_loss=0.0212]
# Epoch 165: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0246, gen_loss=1.02, disc_loss=0.0126]
# Epoch 166: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0224, gen_loss=1.05, disc_loss=0.0136]
# Epoch 167: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0171, gen_loss=1.01, disc_loss=0.0122]
# Epoch 168: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0305, gen_loss=1.07, disc_loss=0.00626]
# Epoch 169: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0257, gen_loss=1.05, disc_loss=0.00375]
# epoch 170 val loss: 0.0160
# Epoch 170: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0283, gen_loss=1.06, disc_loss=0.00311]
# Epoch 171: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0214, gen_loss=1.04, disc_loss=0.00323]
# Epoch 172: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0158, gen_loss=1.04, disc_loss=0.0041]
# Epoch 173: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0211, gen_loss=1.02, disc_loss=0.00992]
# Epoch 174: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0252, gen_loss=0.985, disc_loss=0.0342]
# Epoch 175: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0249, gen_loss=0.968, disc_loss=0.0316]
# Epoch 176: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0217, gen_loss=1.01, disc_loss=0.0118]
# Epoch 177: 100%|████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0234, gen_loss=0.899, disc_loss=0.0479]
# Epoch 178: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0238, gen_loss=1.01, disc_loss=0.0148]
# Epoch 179: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0202, gen_loss=1.01, disc_loss=0.0131]
# epoch 180 val loss: 0.0186
# Epoch 180: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0185, gen_loss=1.05, disc_loss=0.00573]
# Epoch 181: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0163, gen_loss=1.08, disc_loss=0.00365]
# Epoch 182: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0238, gen_loss=1.05, disc_loss=0.00987]
# Epoch 183: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0168, gen_loss=1.03, disc_loss=0.00439]
# Epoch 184: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0165, gen_loss=1.06, disc_loss=0.00678]
# Epoch 185: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.019, gen_loss=0.883, disc_loss=0.0409]
# Epoch 186: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.021, gen_loss=0.901, disc_loss=0.0444]
# Epoch 187: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0268, gen_loss=0.948, disc_loss=0.0376]
# Epoch 188: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0276, gen_loss=0.902, disc_loss=0.0514]
# Epoch 189: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0202, gen_loss=0.98, disc_loss=0.0315]
# Saved better autoencoder model at epoch 190 with val loss: 0.0147
# epoch 190 val loss: 0.0147
# Epoch 190: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0181, gen_loss=1.07, disc_loss=0.0153]
# Epoch 191: 100%|████████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0203, gen_loss=1, disc_loss=0.0387]
# Epoch 192: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0177, gen_loss=0.931, disc_loss=0.0814]
# Epoch 193: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0156, gen_loss=0.817, disc_loss=0.11]
# Epoch 194: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0164, gen_loss=0.868, disc_loss=0.0815]
# Epoch 195: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.016, gen_loss=0.962, disc_loss=0.0371]
# Epoch 196: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0169, gen_loss=1.05, disc_loss=0.0176]
# Epoch 197: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0178, gen_loss=1.01, disc_loss=0.0176]
# Epoch 198: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0241, gen_loss=0.989, disc_loss=0.0206]
# Epoch 199: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0175, gen_loss=1.08, disc_loss=0.00823]
# epoch 200 val loss: 0.0170
# Epoch 200: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0206, gen_loss=1.05, disc_loss=0.00433]
# Epoch 201: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0158, gen_loss=1.06, disc_loss=0.00369]
# Epoch 202: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0194, gen_loss=0.999, disc_loss=0.0112]
# Epoch 203: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0256, gen_loss=1.05, disc_loss=0.00727]
# Epoch 204: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0185, gen_loss=1.05, disc_loss=0.00378]
# Epoch 205: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0199, gen_loss=1.04, disc_loss=0.00576]
# Epoch 206: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0154, gen_loss=1.07, disc_loss=0.00565]
# Epoch 207: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0155, gen_loss=1.04, disc_loss=0.00412]
# Epoch 208: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0158, gen_loss=0.998, disc_loss=0.0217]
# Epoch 209: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0186, gen_loss=0.907, disc_loss=0.0534]
# epoch 210 val loss: 0.0223
# Epoch 210: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0226, gen_loss=0.947, disc_loss=0.0279]
# Epoch 211: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0197, gen_loss=1.02, disc_loss=0.0204]
# Epoch 212: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0143, gen_loss=1.01, disc_loss=0.0133]
# Epoch 213: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0185, gen_loss=1.07, disc_loss=0.0123]
# Epoch 214: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0201, gen_loss=1.02, disc_loss=0.00949]
# Epoch 215: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0166, gen_loss=1.05, disc_loss=0.0146]
# Epoch 216: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0147, gen_loss=1.01, disc_loss=0.00931]
# Epoch 217: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0163, gen_loss=1.08, disc_loss=0.00484]
# Epoch 218: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0149, gen_loss=1.07, disc_loss=0.00327]
# Epoch 219: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.014, gen_loss=1.06, disc_loss=0.00379]
# Saved better autoencoder model at epoch 220 with val loss: 0.0121
# epoch 220 val loss: 0.0121
# Epoch 220: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0155, gen_loss=1.08, disc_loss=0.00275]
# Epoch 221: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0183, gen_loss=1.04, disc_loss=0.00345]
# Epoch 222: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0169, gen_loss=1.07, disc_loss=0.00249]
# Epoch 223: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0248, gen_loss=1.08, disc_loss=0.00342]
# Epoch 224: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0194, gen_loss=1.07, disc_loss=0.00198]
# Epoch 225: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0234, gen_loss=1.09, disc_loss=0.00245]
# Epoch 226: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0162, gen_loss=0.957, disc_loss=0.134]
# Epoch 227: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0167, gen_loss=0.761, disc_loss=0.0858]
# Epoch 228: 100%|█████████| 26/26 [00:19<00:00,  1.36it/s, recons_loss=0.0165, gen_loss=0.736, disc_loss=0.173]
# Epoch 229: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0167, gen_loss=0.85, disc_loss=0.138]
# epoch 230 val loss: 0.0205
# Epoch 230: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0169, gen_loss=0.592, disc_loss=0.194]
# Epoch 231: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0163, gen_loss=0.595, disc_loss=0.245]
# Epoch 232: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0148, gen_loss=0.625, disc_loss=0.254]
# Epoch 233: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0139, gen_loss=0.494, disc_loss=0.352]
# Epoch 234: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0182, gen_loss=0.29, disc_loss=0.263]
# Epoch 235: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0165, gen_loss=0.315, disc_loss=0.238]
# Epoch 236: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0143, gen_loss=0.346, disc_loss=0.254]
# Epoch 237: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0137, gen_loss=0.635, disc_loss=0.167]
# Epoch 238: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0187, gen_loss=0.941, disc_loss=0.0421]
# Epoch 239: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0187, gen_loss=0.968, disc_loss=0.0184]
# epoch 240 val loss: 0.0184
# Epoch 240: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0245, gen_loss=0.922, disc_loss=0.0635]
# Epoch 241: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0224, gen_loss=0.981, disc_loss=0.02]
# Epoch 242: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.017, gen_loss=0.948, disc_loss=0.0447]
# Epoch 243: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0193, gen_loss=0.906, disc_loss=0.049]
# Epoch 244: 100%|██████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0138, gen_loss=0.885, disc_loss=0.04]
# Epoch 245: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0159, gen_loss=0.947, disc_loss=0.0649]
# Epoch 246: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0169, gen_loss=0.743, disc_loss=0.137]
# Epoch 247: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0139, gen_loss=0.936, disc_loss=0.0425]
# Epoch 248: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0174, gen_loss=1.04, disc_loss=0.0266]
# Epoch 249: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.018, gen_loss=0.995, disc_loss=0.023]
# epoch 250 val loss: 0.0154
# Epoch 250: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0159, gen_loss=1.1, disc_loss=0.00889]
# Epoch 251: 100%|██████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.018, gen_loss=0.94, disc_loss=0.0417]
# Epoch 252: 100%|█████████| 26/26 [00:18<00:00,  1.37it/s, recons_loss=0.0194, gen_loss=1.04, disc_loss=0.0225]
# Epoch 253: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0157, gen_loss=0.954, disc_loss=0.0295]
# Epoch 254: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0185, gen_loss=1.08, disc_loss=0.012]
# Epoch 255: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0153, gen_loss=0.995, disc_loss=0.0157]
# Epoch 256: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0147, gen_loss=1.08, disc_loss=0.00779]
# Epoch 257: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0136, gen_loss=1.04, disc_loss=0.0155]
# Epoch 258: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0146, gen_loss=1.04, disc_loss=0.0171]
# Epoch 259: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0177, gen_loss=1.05, disc_loss=0.00793]
# epoch 260 val loss: 0.0202
# Epoch 260: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0208, gen_loss=1.11, disc_loss=0.00564]
# Epoch 261: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0138, gen_loss=1.04, disc_loss=0.0103]
# Epoch 262: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0125, gen_loss=1.05, disc_loss=0.0152]
# Epoch 263: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0138, gen_loss=1.02, disc_loss=0.0263]
# Epoch 264: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0144, gen_loss=0.983, disc_loss=0.0152]
# Epoch 265: 100%|█████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0152, gen_loss=1.04, disc_loss=0.0104]
# Epoch 266: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0165, gen_loss=1.06, disc_loss=0.00687]
# Epoch 267: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0133, gen_loss=1.08, disc_loss=0.00467]
# Epoch 268: 100%|████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0141, gen_loss=1.08, disc_loss=0.00799]
# Epoch 269: 100%|█████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.013, gen_loss=1.08, disc_loss=0.00401]
# Saved better autoencoder model at epoch 270 with val loss: 0.0106
# epoch 270 val loss: 0.0106
# Epoch 270: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.013, gen_loss=1.07, disc_loss=0.00548]
# Epoch 271: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0145, gen_loss=1.05, disc_loss=0.00614]
# Epoch 272: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0202, gen_loss=1.08, disc_loss=0.00329]
# Epoch 273: 100%|██████████| 26/26 [00:18<00:00,  1.39it/s, recons_loss=0.0171, gen_loss=1.05, disc_loss=0.005]
# Epoch 274: 100%|████████| 26/26 [00:18<00:00,  1.38it/s, recons_loss=0.0151, gen_loss=1.07, disc_loss=0.00253]
# Epoch 275: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0132, gen_loss=1.07, disc_loss=0.00241]
# Epoch 276: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0138, gen_loss=1.04, disc_loss=0.00957]
# Epoch 277: 100%|████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0144, gen_loss=1.06, disc_loss=0.00566]
# Epoch 278: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0144, gen_loss=1.02, disc_loss=0.0071]
# Epoch 279: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0138, gen_loss=1.04, disc_loss=0.00441]
# epoch 280 val loss: 0.0154
# Epoch 280: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.016, gen_loss=1.05, disc_loss=0.00382]
# Epoch 281: 100%|█████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0188, gen_loss=1.07, disc_loss=0.0026]
# Epoch 282: 100%|████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0139, gen_loss=1.01, disc_loss=0.00846]
# Epoch 283: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0133, gen_loss=1.06, disc_loss=0.0121]
# Epoch 284: 100%|███████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0128, gen_loss=1, disc_loss=0.00527]
# Epoch 285: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.0148, gen_loss=1.01, disc_loss=0.0291]
# Epoch 286: 100%|█████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.014, gen_loss=0.901, disc_loss=0.0393]
# Epoch 287: 100%|██████████| 26/26 [00:18<00:00,  1.41it/s, recons_loss=0.018, gen_loss=1.05, disc_loss=0.0145]
# Epoch 288: 100%|█████████| 26/26 [00:18<00:00,  1.40it/s, recons_loss=0.0193, gen_loss=0.85, disc_loss=0.0552]
# Epoch 289: 100%|████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0162, gen_loss=0.987, disc_loss=0.0285]
# epoch 290 val loss: 0.0200
# Epoch 290: 100%|█████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0165, gen_loss=0.949, disc_loss=0.033]
# Epoch 291: 100%|████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0138, gen_loss=0.957, disc_loss=0.0592]
# Epoch 292: 100%|████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0149, gen_loss=0.949, disc_loss=0.0338]
# Epoch 293: 100%|█████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0147, gen_loss=1.09, disc_loss=0.0103]
# Epoch 294: 100%|████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0191, gen_loss=1.06, disc_loss=0.00873]
# Epoch 295: 100%|█████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0149, gen_loss=1.05, disc_loss=0.0187]
# Epoch 296: 100%|██████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.016, gen_loss=1.08, disc_loss=0.0104]
# Epoch 297: 100%|████████| 26/26 [00:18<00:00,  1.44it/s, recons_loss=0.0142, gen_loss=0.991, disc_loss=0.0185]
# Epoch 298: 100%|█████████| 26/26 [00:18<00:00,  1.43it/s, recons_loss=0.0155, gen_loss=1.05, disc_loss=0.0129]
# Epoch 299: 100%|██████████| 26/26 [00:18<00:00,  1.42it/s, recons_loss=0.0135, gen_loss=0.9, disc_loss=0.0441]
# epoch 300 val loss: 0.0161

# %%
# Plot last 5 evaluations
val_samples = np.linspace(n_epochs, val_interval, int(n_epochs / val_interval))
fig, ax = plt.subplots(nrows=5, ncols=1, sharey=True)
for image_n in range(5):
    reconstructions = torch.reshape(intermediary_images[image_n], (image_size * num_example_images, image_size)).T
    ax[image_n].imshow(reconstructions.cpu(), cmap="gray")
    ax[image_n].set_xticks([])
    ax[image_n].set_yticks([])
    ax[image_n].set_ylabel(f"Epoch {val_samples[image_n]:.0f}")

# %%
unet = DiffusionModelUNet(
    spatial_dims=2,
    in_channels=3,
    out_channels=3,
    num_res_blocks=2,
    num_channels=(128, 256, 512),
    attention_levels=(False, True, True),
    num_head_channels=(0, 256, 512),
)

scheduler = DDPMScheduler(num_train_timesteps=1000, schedule="linear_beta", beta_start=0.0015, beta_end=0.0195)

# %%
check_data = first(train_loader)
fig, ax = plt.subplots(nrows=1, ncols=3)
for image_n in range(3):
    ax[image_n].imshow(check_data["image"][image_n, 0, :, :].T, cmap="gray")
    ax[image_n].axis("off")

# %%
autoencoderkl.load_state_dict(torch.load(os.path.join(model_path, f"{gen_type}_best_autoencoderkl.pth")))
autoencoderkl.eval()
# Out:
# AutoencoderKL(
#   (encoder): Encoder(
#     (blocks): ModuleList(
#       (0): Convolution(
#         (conv): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1-2): 2 x ResBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (3): Downsample(
#         (conv): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#         )
#       )
#       (4-5): 2 x ResBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (6): Downsample(
#         (conv): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#         )
#       )
#       (7): ResBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Convolution(
#           (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (8): ResBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (9): GroupNorm(32, 256, eps=1e-06, affine=True)
#       (10): Convolution(
#         (conv): Conv2d(256, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (decoder): Decoder(
#     (blocks): ModuleList(
#       (0): Convolution(
#         (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1-2): 2 x ResBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (3): Upsample(
#         (conv): Convolution(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (4): ResBlock(
#         (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Convolution(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): ResBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (6): Upsample(
#         (conv): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (7-8): 2 x ResBlock(
#         (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv1): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#         (conv2): Convolution(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (nin_shortcut): Identity()
#       )
#       (9): GroupNorm(32, 128, eps=1e-06, affine=True)
#       (10): Convolution(
#         (conv): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (quant_conv_mu): Convolution(
#     (conv): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (quant_conv_log_sigma): Convolution(
#     (conv): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (post_quant_conv): Convolution(
#     (conv): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
with torch.no_grad():
    with autocast(enabled=True):
        # z = autoencoderkl.encode_stage_2_inputs(check_data["image"].to(device))
        z = autoencoderkl.encode_stage_2_inputs(check_data["image"].to(device))

print(f"Scaling factor set to {1/torch.std(z)}")
scale_factor = 1 / torch.std(z)
# Out:
# Scaling factor set to 0.9436339735984802

# %%
inferer = LatentDiffusionInferer(scheduler, scale_factor=scale_factor)

# %%
optimizer = torch.optim.Adam(unet.parameters(), lr=1e-4)

unet = unet.to(device)
n_epochs = 300
val_interval = 20
epoch_losses = []
val_losses = []
scaler = GradScaler()

best_val_loss = float('inf')  

for epoch in range(n_epochs):
    unet.train()
    autoencoderkl.eval()
    # autoencoderkl.eval()
    epoch_loss = 0
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), ncols=70)
    progress_bar.set_description(f"Epoch {epoch}")
    for step, batch in progress_bar:
        images = batch["image"].to(device)
        optimizer.zero_grad(set_to_none=True)
        with autocast(enabled=True):
            # z_mu, z_sigma = autoencoderkl.module.encode(images)
            z_mu, z_sigma = autoencoderkl.encode(images)
            # z = autoencoderkl.module.sampling(z_mu, z_sigma)
            z = autoencoderkl.sampling(z_mu, z_sigma)
            noise = torch.randn_like(z).to(device)
            timesteps = torch.randint(0, inferer.scheduler.num_train_timesteps, (z.shape[0],), device=z.device).long()
            noise_pred = inferer(
                inputs=images, diffusion_model=unet, noise=noise, timesteps=timesteps, autoencoder_model=autoencoderkl
            )
            loss = F.mse_loss(noise_pred.float(), noise.float())

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        epoch_loss += loss.item()

        progress_bar.set_postfix({"loss": epoch_loss / (step + 1)})
    epoch_losses.append(epoch_loss / (step + 1))

    if (epoch + 1) % val_interval == 0:
        unet.eval()
        val_loss = 0
        with torch.no_grad():
            for val_step, batch in enumerate(val_loader, start=1):
                images = batch["image"].to(device)

                with autocast(enabled=True):
                    # z_mu, z_sigma = autoencoderkl.module.encode(images)
                    z_mu, z_sigma = autoencoderkl.encode(images)
                    # z = autoencoderkl.module.sampling(z_mu, z_sigma)
                    z = autoencoderkl.sampling(z_mu, z_sigma)

                    noise = torch.randn_like(z).to(device)
                    timesteps = torch.randint(
                        0, inferer.scheduler.num_train_timesteps, (z.shape[0],), device=z.device
                    ).long()
                    noise_pred = inferer(
                        inputs=images,
                        diffusion_model=unet,
                        noise=noise,
                        timesteps=timesteps,
                        autoencoder_model=autoencoderkl,
                    )

                    loss = F.mse_loss(noise_pred.float(), noise.float())

                val_loss += loss.item()
        val_loss /= val_step
        val_losses.append(val_loss)
        print(f"Epoch {epoch} val loss: {val_loss:.4f}")

        # Save the model if it has the best validation loss so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(unet.state_dict(), os.path.join(model_path, f"{gen_type}_best_unet_model.pth"))

            print(f"Saved improved model with validation loss {best_val_loss:.4f}")
        
        # Sampling image during training
        z = torch.randn((1, 3, 32, 32))
        z = z.to(device)
        scheduler.set_timesteps(num_inference_steps=1000)
        with autocast(enabled=True):
            decoded = inferer.sample(
                input_noise=z, diffusion_model=unet, scheduler=scheduler, autoencoder_model=autoencoderkl
            )

        plt.figure(figsize=(2, 2))
        plt.style.use("default")
        plt.imshow(decoded[0, 0].detach().cpu(), vmin=0, vmax=1, cmap="gray")
        plt.tight_layout()
        plt.axis("off")
        plt.show()
progress_bar.close()
# Out:
# Epoch 0:  96%|███████████▌| 25/26 [00:05<00:00,  4.48it/s, loss=0.802]/home/chilin/.pyenv/versions/3.9.13/envs/Gen2/lib/python3.9/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 0: 100%|█████████████| 26/26 [00:06<00:00,  4.12it/s, loss=0.79]
# Epoch 1: 100%|████████████| 26/26 [00:06<00:00,  4.22it/s, loss=0.436]
# Epoch 2: 100%|████████████| 26/26 [00:07<00:00,  3.54it/s, loss=0.271]
# Epoch 3: 100%|████████████| 26/26 [00:08<00:00,  3.02it/s, loss=0.187]
# Epoch 4: 100%|████████████| 26/26 [00:08<00:00,  2.95it/s, loss=0.171]
# Epoch 5: 100%|████████████| 26/26 [00:08<00:00,  2.91it/s, loss=0.161]
# Epoch 6: 100%|████████████| 26/26 [00:09<00:00,  2.82it/s, loss=0.145]
# Epoch 7: 100%|████████████| 26/26 [00:09<00:00,  2.83it/s, loss=0.147]
# Epoch 8: 100%|████████████| 26/26 [00:09<00:00,  2.81it/s, loss=0.146]
# Epoch 9: 100%|█████████████| 26/26 [00:09<00:00,  2.77it/s, loss=0.13]
# Epoch 10: 100%|███████████| 26/26 [00:09<00:00,  2.70it/s, loss=0.159]
# Epoch 11: 100%|███████████| 26/26 [00:09<00:00,  2.66it/s, loss=0.145]
# Epoch 12: 100%|███████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.151]
# Epoch 13: 100%|███████████| 26/26 [00:09<00:00,  2.66it/s, loss=0.148]
# Epoch 14: 100%|███████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.149]
# Epoch 15: 100%|███████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.156]
# Epoch 16: 100%|███████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.143]
# Epoch 17: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.128]
# Epoch 18: 100%|███████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.139]
# Epoch 19: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.151]
# Epoch 19 val loss: 0.1251
# Saved improved model with validation loss 0.1251
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 83.15it/s]
# Epoch 20: 100%|████████████| 26/26 [00:08<00:00,  3.01it/s, loss=0.13]
# Epoch 21: 100%|███████████| 26/26 [00:09<00:00,  2.65it/s, loss=0.148]
# Epoch 22: 100%|███████████| 26/26 [00:09<00:00,  2.68it/s, loss=0.141]
# Epoch 23: 100%|███████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.145]
# Epoch 24: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.145]
# Epoch 25: 100%|███████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.131]
# Epoch 26: 100%|███████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.135]
# Epoch 27: 100%|████████████| 26/26 [00:09<00:00,  2.66it/s, loss=0.14]
# Epoch 28: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.128]
# Epoch 29: 100%|███████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.144]
# Epoch 30: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.142]
# Epoch 31: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.149]
# Epoch 32: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.141]
# Epoch 33: 100%|███████████| 26/26 [00:09<00:00,  2.65it/s, loss=0.138]
# Epoch 34: 100%|███████████| 26/26 [00:09<00:00,  2.65it/s, loss=0.126]
# Epoch 35: 100%|███████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.152]
# Epoch 36: 100%|███████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.137]
# Epoch 37: 100%|███████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.137]
# Epoch 38: 100%|████████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.14]
# Epoch 39: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.136]
# Epoch 39 val loss: 0.1361
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 80.26it/s]
# Epoch 40: 100%|███████████| 26/26 [00:08<00:00,  2.96it/s, loss=0.143]
# Epoch 41: 100%|███████████| 26/26 [00:09<00:00,  2.66it/s, loss=0.142]
# Epoch 42: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.148]
# Epoch 43: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.155]
# Epoch 44: 100%|████████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.15]
# Epoch 45: 100%|███████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.137]
# Epoch 46: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.139]
# Epoch 47: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.136]
# Epoch 48: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.137]
# Epoch 49: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.143]
# Epoch 50: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.131]
# Epoch 51: 100%|███████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.128]
# Epoch 52: 100%|████████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.14]
# Epoch 53: 100%|███████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.151]
# Epoch 54: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.134]
# Epoch 55: 100%|███████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.136]
# Epoch 56: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.119]
# Epoch 57: 100%|███████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.125]
# Epoch 58: 100%|███████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.156]
# Epoch 59: 100%|███████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.131]
# Epoch 59 val loss: 0.1531
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 79.91it/s]
# Epoch 60: 100%|███████████| 26/26 [00:08<00:00,  2.95it/s, loss=0.147]
# Epoch 61: 100%|███████████| 26/26 [00:09<00:00,  2.65it/s, loss=0.138]
# Epoch 62: 100%|███████████| 26/26 [00:09<00:00,  2.66it/s, loss=0.141]
# Epoch 63: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.136]
# Epoch 64: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.155]
# Epoch 65: 100%|███████████| 26/26 [00:10<00:00,  2.52it/s, loss=0.147]
# Epoch 66: 100%|███████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.124]
# Epoch 67: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.144]
# Epoch 68: 100%|████████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.13]
# Epoch 69: 100%|███████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.143]
# Epoch 70: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.148]
# Epoch 71: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.134]
# Epoch 72: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.136]
# Epoch 73: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.119]
# Epoch 74: 100%|███████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.134]
# Epoch 75: 100%|████████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.14]
# Epoch 76: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.138]
# Epoch 77: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.131]
# Epoch 78: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.134]
# Epoch 79: 100%|███████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.128]
# Epoch 79 val loss: 0.1472
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 79.73it/s]
# Epoch 80: 100%|███████████| 26/26 [00:08<00:00,  2.95it/s, loss=0.133]
# Epoch 81: 100%|███████████| 26/26 [00:09<00:00,  2.69it/s, loss=0.142]
# Epoch 82: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.127]
# Epoch 83: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.137]
# Epoch 84: 100%|████████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.13]
# Epoch 85: 100%|███████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.142]
# Epoch 86: 100%|███████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.129]
# Epoch 87: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.134]
# Epoch 88: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.134]
# Epoch 89: 100%|███████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.141]
# Epoch 90: 100%|███████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.135]
# Epoch 91: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.139]
# Epoch 92: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.126]
# Epoch 93: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.133]
# Epoch 94: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.144]
# Epoch 95: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.131]
# Epoch 96: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.126]
# Epoch 97: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.127]
# Epoch 98: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.143]
# Epoch 99: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.129]
# Epoch 99 val loss: 0.1377
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 81.24it/s]
# Epoch 100: 100%|███████████| 26/26 [00:08<00:00,  2.93it/s, loss=0.13]
# Epoch 101: 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.132]
# Epoch 102: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.134]
# Epoch 103: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.139]
# Epoch 104: 100%|███████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.13]
# Epoch 105: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.131]
# Epoch 106: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.132]
# Epoch 107: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.126]
# Epoch 108: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.148]
# Epoch 109: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.134]
# Epoch 110: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.112]
# Epoch 111: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.129]
# Epoch 112: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.143]
# Epoch 113: 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.132]
# Epoch 114: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.152]
# Epoch 115: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.132]
# Epoch 116: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.136]
# Epoch 117: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.136]
# Epoch 118: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.124]
# Epoch 119: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.146]
# Epoch 119 val loss: 0.1575
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 80.96it/s]
# Epoch 120: 100%|██████████| 26/26 [00:08<00:00,  2.93it/s, loss=0.143]
# Epoch 121: 100%|██████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.135]
# Epoch 122: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.142]
# Epoch 123: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.131]
# Epoch 124: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.121]
# Epoch 125: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.136]
# Epoch 126: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.133]
# Epoch 127: 100%|██████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.129]
# Epoch 128: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.124]
# Epoch 129: 100%|███████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.13]
# Epoch 130: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.145]
# Epoch 131: 100%|███████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.14]
# Epoch 132: 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.143]
# Epoch 133: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.146]
# Epoch 134: 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.129]
# Epoch 135: 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.124]
# Epoch 136: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.126]
# Epoch 137: 100%|███████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.14]
# Epoch 138: 100%|██████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.145]
# Epoch 139: 100%|██████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.141]
# Epoch 139 val loss: 0.1405
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 82.39it/s]
# Epoch 140: 100%|██████████| 26/26 [00:08<00:00,  2.91it/s, loss=0.131]
# Epoch 141: 100%|██████████| 26/26 [00:09<00:00,  2.71it/s, loss=0.142]
# Epoch 142: 100%|██████████| 26/26 [00:09<00:00,  2.64it/s, loss=0.131]
# Epoch 143: 100%|██████████| 26/26 [00:09<00:00,  2.63it/s, loss=0.141]
# Epoch 144: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.125]
# Epoch 145: 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.134]
# Epoch 146: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.142]
# Epoch 147: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.131]
# Epoch 148: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.135]
# Epoch 149: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.13]
# Epoch 150: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.119]
# Epoch 151: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.125]
# Epoch 152: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.145]
# Epoch 153: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.161]
# Epoch 154: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.136]
# Epoch 155: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.138]
# Epoch 156: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.131]
# Epoch 157: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.118]
# Epoch 158: 100%|██████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.132]
# Epoch 159: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.141]
# Epoch 159 val loss: 0.1299
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 78.90it/s]
# Epoch 160: 100%|██████████| 26/26 [00:08<00:00,  2.93it/s, loss=0.134]
# Epoch 161: 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.137]
# Epoch 162: 100%|███████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.14]
# Epoch 163: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.141]
# Epoch 164: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.112]
# Epoch 165: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.127]
# Epoch 166: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.133]
# Epoch 167: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.119]
# Epoch 168: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.121]
# Epoch 169: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.117]
# Epoch 170: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.146]
# Epoch 171: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.124]
# Epoch 172: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.131]
# Epoch 173: 100%|███████████| 26/26 [00:10<00:00,  2.52it/s, loss=0.13]
# Epoch 174: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.13]
# Epoch 175: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.127]
# Epoch 176: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.133]
# Epoch 177: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.149]
# Epoch 178: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.126]
# Epoch 179: 100%|██████████| 26/26 [00:10<00:00,  2.52it/s, loss=0.118]
# Epoch 179 val loss: 0.1210
# Saved improved model with validation loss 0.1210
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 83.14it/s]
# Epoch 180: 100%|██████████| 26/26 [00:09<00:00,  2.86it/s, loss=0.132]
# Epoch 181: 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.136]
# Epoch 182: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.146]
# Epoch 183: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.137]
# Epoch 184: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.129]
# Epoch 185: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.134]
# Epoch 186: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.136]
# Epoch 187: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.12]
# Epoch 188: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.148]
# Epoch 189: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.127]
# Epoch 190: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.125]
# Epoch 191: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.127]
# Epoch 192: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.143]
# Epoch 193: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.136]
# Epoch 194: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.125]
# Epoch 195: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.136]
# Epoch 196: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.122]
# Epoch 197: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.127]
# Epoch 198: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.127]
# Epoch 199: 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.129]
# Epoch 199 val loss: 0.1239
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 81.54it/s]
# Epoch 200: 100%|███████████| 26/26 [00:09<00:00,  2.88it/s, loss=0.14]
# Epoch 201: 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.143]
# Epoch 202: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.145]
# Epoch 203: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.143]
# Epoch 204: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.133]
# Epoch 205: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.149]
# Epoch 206: 100%|███████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.13]
# Epoch 207: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.12]
# Epoch 208: 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.119]
# Epoch 209: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.131]
# Epoch 210: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.135]
# Epoch 211: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.141]
# Epoch 212: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.128]
# Epoch 213: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.118]
# Epoch 214: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.132]
# Epoch 215: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.137]
# Epoch 216: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.123]
# Epoch 217: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.125]
# Epoch 218: 100%|██████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.117]
# Epoch 219: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.128]
# Epoch 219 val loss: 0.1318
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 82.72it/s]
# Epoch 220: 100%|██████████| 26/26 [00:09<00:00,  2.86it/s, loss=0.129]
# Epoch 221: 100%|██████████| 26/26 [00:09<00:00,  2.65it/s, loss=0.129]
# Epoch 222: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.125]
# Epoch 223: 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.134]
# Epoch 224: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.128]
# Epoch 225: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.14]
# Epoch 226: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.132]
# Epoch 227: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.119]
# Epoch 228: 100%|██████████| 26/26 [00:10<00:00,  2.51it/s, loss=0.129]
# Epoch 229: 100%|███████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.13]
# Epoch 230: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.116]
# Epoch 231: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.112]
# Epoch 232: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.135]
# Epoch 233: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.139]
# Epoch 234: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.123]
# Epoch 235: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.115]
# Epoch 236: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.134]
# Epoch 237: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.131]
# Epoch 238: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.126]
# Epoch 239: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.132]
# Epoch 239 val loss: 0.1611
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 79.98it/s]
# Epoch 240: 100%|██████████| 26/26 [00:08<00:00,  2.90it/s, loss=0.131]
# Epoch 241: 100%|██████████| 26/26 [00:09<00:00,  2.61it/s, loss=0.147]
# Epoch 242: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.133]
# Epoch 243: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.132]
# Epoch 244: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.14]
# Epoch 245: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.134]
# Epoch 246: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.133]
# Epoch 247: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.127]
# Epoch 248: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.129]
# Epoch 249: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.117]
# Epoch 250: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.142]
# Epoch 251: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.142]
# Epoch 252: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.131]
# Epoch 253: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.112]
# Epoch 254: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.151]
# Epoch 255: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.139]
# Epoch 256: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.121]
# Epoch 257: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.125]
# Epoch 258: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.138]
# Epoch 259: 100%|██████████| 26/26 [00:09<00:00,  2.60it/s, loss=0.124]
# Epoch 259 val loss: 0.1144
# Saved improved model with validation loss 0.1144
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 80.10it/s]
# Epoch 260: 100%|██████████| 26/26 [00:08<00:00,  2.92it/s, loss=0.131]
# Epoch 261: 100%|██████████| 26/26 [00:09<00:00,  2.67it/s, loss=0.128]
# Epoch 262: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.13]
# Epoch 263: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.13]
# Epoch 264: 100%|███████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.13]
# Epoch 265: 100%|██████████| 26/26 [00:10<00:00,  2.52it/s, loss=0.123]
# Epoch 266: 100%|██████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.145]
# Epoch 267: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.127]
# Epoch 268: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.131]
# Epoch 269: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.153]
# Epoch 270: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.126]
# Epoch 271: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.147]
# Epoch 272: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.138]
# Epoch 273: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.125]
# Epoch 274: 100%|██████████| 26/26 [00:10<00:00,  2.53it/s, loss=0.134]
# Epoch 275: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.128]
# Epoch 276: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.101]
# Epoch 277: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.146]
# Epoch 278: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.124]
# Epoch 279: 100%|██████████| 26/26 [00:10<00:00,  2.49it/s, loss=0.133]
# Epoch 279 val loss: 0.1592
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:13<00:00, 74.49it/s]
# Epoch 280: 100%|██████████| 26/26 [00:08<00:00,  2.89it/s, loss=0.137]
# Epoch 281: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.155]
# Epoch 282: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.131]
# Epoch 283: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.129]
# Epoch 284: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.121]
# Epoch 285: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.146]
# Epoch 286: 100%|███████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.14]
# Epoch 287: 100%|██████████| 26/26 [00:10<00:00,  2.56it/s, loss=0.152]
# Epoch 288: 100%|███████████| 26/26 [00:10<00:00,  2.57it/s, loss=0.15]
# Epoch 289: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.131]
# Epoch 290: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.123]
# Epoch 291: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.116]
# Epoch 292: 100%|██████████| 26/26 [00:10<00:00,  2.54it/s, loss=0.114]
# Epoch 293: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.148]
# Epoch 294: 100%|██████████| 26/26 [00:10<00:00,  2.50it/s, loss=0.131]
# Epoch 295: 100%|██████████| 26/26 [00:10<00:00,  2.55it/s, loss=0.119]
# Epoch 296: 100%|███████████| 26/26 [00:10<00:00,  2.58it/s, loss=0.12]
# Epoch 297: 100%|██████████| 26/26 [00:10<00:00,  2.60it/s, loss=0.128]
# Epoch 298: 100%|██████████| 26/26 [00:10<00:00,  2.59it/s, loss=0.132]
# Epoch 299: 100%|██████████| 26/26 [00:09<00:00,  2.62it/s, loss=0.121]
# Epoch 299 val loss: 0.1297
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:12<00:00, 81.09it/s]

# %%
plt.figure()
plt.title("Learning Curves", fontsize=20)
plt.plot(np.linspace(1, n_epochs, n_epochs), epoch_losses, linewidth=2.0, label="Train")
plt.plot(
    np.linspace(val_interval, n_epochs, int(n_epochs / val_interval)), val_losses, linewidth=2.0, label="Validation"
)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.xlabel("Epochs", fontsize=16)
plt.ylabel("Loss", fontsize=16)
plt.legend(prop={"size": 14})

# %%
unet.eval()
scheduler.set_timesteps(num_inference_steps=1000)
noise = torch.randn((1, 3, 32, 32))
noise = noise.to(device)

with torch.no_grad():
    image, intermediates = inferer.sample(
        input_noise=noise,
        diffusion_model=unet,
        scheduler=scheduler,
        save_intermediates=True,
        intermediate_steps=100,
        autoencoder_model=autoencoderkl,
    )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:09<00:00, 100.53it/s]

# %%
# Decode latent representation of the intermediary images
decoded_images = []
for image in intermediates:
    with torch.no_grad():
        decoded_images.append(image)
plt.figure(figsize=(10, 12))
chain = torch.cat(decoded_images, dim=-1)
plt.style.use("default")
plt.imshow(chain[0, 0].cpu(), vmin=0, vmax=1, cmap="gray")
plt.tight_layout()
plt.axis("off")
# Out:
# (-0.5, 1279.5, 127.5, -0.5)

# %%
image.shape
# Out:
# torch.Size([1, 3, 128, 128])

# %%
import torchvision.transforms.functional as F

for i in image:
    plt.figure(figsize=(2, 2))
    # chain = torch.cat(image, dim=-1)
    plt.style.use("default")
    plt.imshow(F.to_pil_image(i.cpu()), vmin=0, vmax=1, cmap="gray")
    plt.tight_layout()
    plt.axis("off")
    plt.tight_layout()
    plt.show()
    plt.close()
